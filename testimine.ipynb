# %%
import pandas as pd

# %%
data = pd.read_csv("nobel_prizes_1901-2025_cleaned.csv")

# %%
data.head()
# Out:
#    award_year date_awarded  prize_amount  prize_amount_adjusted  laureate_id  \
# 0        1901   11/12/1901        150782               10833458        160.0
# 1        1901   11/14/1901        150782               10833458        569.0
# 2        1901   12/10/1901        150782               10833458        462.0
# 3        1901   12/10/1901        150782               10833458        463.0
# 4        1901   11/12/1901        150782               10833458          1.0
#
#                known_name                     full_name   sex  portion  \
# 0  Jacobus H. van 't Hoff  Jacobus Henricus van 't Hoff  male      1.0
# 1         Sully Prudhomme               Sully Prudhomme  male      1.0
# 2            Henry Dunant             Jean Henry Dunant  male      0.5
# 3          Frédéric Passy                Frédéric Passy  male      0.5
# 4  Wilhelm Conrad Röntgen        Wilhelm Conrad Röntgen  male      1.0
#
# ...

# %%
data.shape
# Out:
# (995, 33)
